# %%
cur_x=3
rate=0.01
precision=0.000001
previous_step_size=1
max_iters=10000
iters=0
df=lambda x:2*(x+5)

# %%
while previous_step_size>precision and iters<max_iters:
    prev_x=cur_x
    cur_x=cur_x- rate* df(prev_x)
    previous_step_size= abs(cur_x - prev_x)
    iters=iters+1
    print("Iteration is ",iters ,"\n value is :",cur_x)
    print("local minimum occurs at ", cur_x)
# Out:
# Iteration is  1
#  value is : 2.84
# local minimum occurs at  2.84
# Iteration is  2
#  value is : 2.6832
# local minimum occurs at  2.6832
# Iteration is  3
#  value is : 2.529536
# local minimum occurs at  2.529536
# Iteration is  4
#  value is : 2.37894528
# local minimum occurs at  2.37894528
# Iteration is  5
#  value is : 2.2313663744
# local minimum occurs at  2.2313663744
# Iteration is  6
#  value is : 2.0867390469119997
# local minimum occurs at  2.0867390469119997
# Iteration is  7
#  value is : 1.9450042659737599
# local minimum occurs at  1.9450042659737599
# Iteration is  8
#  value is : 1.8061041806542846
# local minimum occurs at  1.8061041806542846
# Iteration is  9
#  value is : 1.669982097041199
# local minimum occurs at  1.669982097041199
# Iteration is  10
#  value is : 1.5365824551003748
# local minimum occurs at  1.5365824551003748
# Iteration is  11
#  value is : 1.4058508059983674
# local minimum occurs at  1.4058508059983674
# Iteration is  12
#  value is : 1.2777337898784
# local minimum occurs at  1.2777337898784
# Iteration is  13
#  value is : 1.152179114080832
# local minimum occurs at  1.152179114080832
# Iteration is  14
#  value is : 1.0291355317992152
# local minimum occurs at  1.0291355317992152
# Iteration is  15
#  value is : 0.9085528211632309
# local minimum occurs at  0.9085528211632309
# Iteration is  16
#  value is : 0.7903817647399662
# local minimum occurs at  0.7903817647399662
# Iteration is  17
#  value is : 0.6745741294451669
# local minimum occurs at  0.6745741294451669
# Iteration is  18
#  value is : 0.5610826468562635
# local minimum occurs at  0.5610826468562635
# Iteration is  19
#  value is : 0.44986099391913825
# local minimum occurs at  0.44986099391913825
# Iteration is  20
#  value is : 0.3408637740407555
# local minimum occurs at  0.3408637740407555
# Iteration is  21
#  value is : 0.23404649855994042
# local minimum occurs at  0.23404649855994042
# Iteration is  22
#  value is : 0.1293655685887416
# local minimum occurs at  0.1293655685887416
# Iteration is  23
#  value is : 0.026778257216966764
# local minimum occurs at  0.026778257216966764
# Iteration is  24
#  value is : -0.07375730792737258
# local minimum occurs at  -0.07375730792737258
# Iteration is  25
#  value is : -0.1722821617688251
# local minimum occurs at  -0.1722821617688251
# Iteration is  26
#  value is : -0.2688365185334486
# local minimum occurs at  -0.2688365185334486
# Iteration is  27
#  value is : -0.36345978816277963
# local minimum occurs at  -0.36345978816277963
# Iteration is  28
#  value is : -0.45619059239952403
# local minimum occurs at  -0.45619059239952403
# Iteration is  29
#  value is : -0.5470667805515336
# local minimum occurs at  -0.5470667805515336
# Iteration is  30
#  value is : -0.6361254449405029
# local minimum occurs at  -0.6361254449405029
# Iteration is  31
#  value is : -0.7234029360416929
# local minimum occurs at  -0.7234029360416929
# Iteration is  32
#  value is : -0.8089348773208591
# local minimum occurs at  -0.8089348773208591
# Iteration is  33
#  value is : -0.8927561797744419
# local minimum occurs at  -0.8927561797744419
# Iteration is  34
#  value is : -0.9749010561789531
# local minimum occurs at  -0.9749010561789531
# Iteration is  35
#  value is : -1.055403035055374
# local minimum occurs at  -1.055403035055374
# Iteration is  36
#  value is : -1.1342949743542665
# local minimum occurs at  -1.1342949743542665
# Iteration is  37
#  value is : -1.2116090748671813
# local minimum occurs at  -1.2116090748671813
# Iteration is  38
#  value is : -1.2873768933698377
# local minimum occurs at  -1.2873768933698377
# Iteration is  39
#  value is : -1.361629355502441
# local minimum occurs at  -1.361629355502441
# Iteration is  40
#  value is : -1.4343967683923922
# local minimum occurs at  -1.4343967683923922
# Iteration is  41
#  value is : -1.5057088330245443
# local minimum occurs at  -1.5057088330245443
# Iteration is  42
#  value is : -1.5755946563640535
# local minimum occurs at  -1.5755946563640535
# Iteration is  43
#  value is : -1.6440827632367725
# local minimum occurs at  -1.6440827632367725
# Iteration is  44
#  value is : -1.711201107972037
# local minimum occurs at  -1.711201107972037
# Iteration is  45
#  value is : -1.7769770858125964
# local minimum occurs at  -1.7769770858125964
# Iteration is  46
#  value is : -1.8414375440963444
# local minimum occurs at  -1.8414375440963444
# Iteration is  47
#  value is : -1.9046087932144176
# local minimum occurs at  -1.9046087932144176
# Iteration is  48
#  value is : -1.9665166173501292
# local minimum occurs at  -1.9665166173501292
# Iteration is  49
#  value is : -2.0271862850031264
# local minimum occurs at  -2.0271862850031264
# Iteration is  50
#  value is : -2.0866425593030637
# local minimum occurs at  -2.0866425593030637
# Iteration is  51
#  value is : -2.1449097081170025
# local minimum occurs at  -2.1449097081170025
# Iteration is  52
#  value is : -2.2020115139546625
# local minimum occurs at  -2.2020115139546625
# Iteration is  53
#  value is : -2.257971283675569
# local minimum occurs at  -2.257971283675569
# Iteration is  54
#  value is : -2.312811858002058
# local minimum occurs at  -2.312811858002058
# Iteration is  55
#  value is : -2.3665556208420164
# local minimum occurs at  -2.3665556208420164
# Iteration is  56
#  value is : -2.419224508425176
# local minimum occurs at  -2.419224508425176
# Iteration is  57
#  value is : -2.4708400182566725
# local minimum occurs at  -2.4708400182566725
# Iteration is  58
#  value is : -2.521423217891539
# local minimum occurs at  -2.521423217891539
# Iteration is  59
#  value is : -2.570994753533708
# local minimum occurs at  -2.570994753533708
# Iteration is  60
#  value is : -2.619574858463034
# local minimum occurs at  -2.619574858463034
# Iteration is  61
#  value is : -2.667183361293773
# local minimum occurs at  -2.667183361293773
# Iteration is  62
#  value is : -2.713839694067898
# local minimum occurs at  -2.713839694067898
# Iteration is  63
#  value is : -2.75956290018654
# local minimum occurs at  -2.75956290018654
# Iteration is  64
#  value is : -2.804371642182809
# local minimum occurs at  -2.804371642182809
# Iteration is  65
#  value is : -2.8482842093391527
# local minimum occurs at  -2.8482842093391527
# Iteration is  66
#  value is : -2.8913185251523696
# local minimum occurs at  -2.8913185251523696
# Iteration is  67
#  value is : -2.9334921546493224
# local minimum occurs at  -2.9334921546493224
# Iteration is  68
#  value is : -2.974822311556336
# local minimum occurs at  -2.974822311556336
# Iteration is  69
#  value is : -3.015325865325209
# local minimum occurs at  -3.015325865325209
# Iteration is  70
#  value is : -3.055019348018705
# local minimum occurs at  -3.055019348018705
# Iteration is  71
#  value is : -3.093918961058331
# local minimum occurs at  -3.093918961058331
# Iteration is  72
#  value is : -3.1320405818371646
# local minimum occurs at  -3.1320405818371646
# Iteration is  73
#  value is : -3.1693997702004215
# local minimum occurs at  -3.1693997702004215
# Iteration is  74
#  value is : -3.206011774796413
# local minimum occurs at  -3.206011774796413
# Iteration is  75
#  value is : -3.2418915393004846
# local minimum occurs at  -3.2418915393004846
# Iteration is  76
#  value is : -3.277053708514475
# local minimum occurs at  -3.277053708514475
# Iteration is  77
#  value is : -3.3115126343441856
# local minimum occurs at  -3.3115126343441856
# Iteration is  78
#  value is : -3.345282381657302
# local minimum occurs at  -3.345282381657302
# Iteration is  79
#  value is : -3.378376734024156
# local minimum occurs at  -3.378376734024156
# Iteration is  80
#  value is : -3.4108091993436727
# local minimum occurs at  -3.4108091993436727
# Iteration is  81
#  value is : -3.4425930153567994
# local minimum occurs at  -3.4425930153567994
# Iteration is  82
#  value is : -3.4737411550496633
# local minimum occurs at  -3.4737411550496633
# Iteration is  83
#  value is : -3.50426633194867
# local minimum occurs at  -3.50426633194867
# Iteration is  84
#  value is : -3.534181005309697
# local minimum occurs at  -3.534181005309697
# Iteration is  85
#  value is : -3.563497385203503
# local minimum occurs at  -3.563497385203503
# Iteration is  86
#  value is : -3.5922274374994325
# local minimum occurs at  -3.5922274374994325
# Iteration is  87
#  value is : -3.620382888749444
# local minimum occurs at  -3.620382888749444
# Iteration is  88
#  value is : -3.6479752309744553
# local minimum occurs at  -3.6479752309744553
# Iteration is  89
#  value is : -3.675015726354966
# local minimum occurs at  -3.675015726354966
# Iteration is  90
#  value is : -3.7015154118278666
# local minimum occurs at  -3.7015154118278666
# Iteration is  91
#  value is : -3.7274851035913095
# local minimum occurs at  -3.7274851035913095
# Iteration is  92
#  value is : -3.7529354015194833
# local minimum occurs at  -3.7529354015194833
# Iteration is  93
#  value is : -3.7778766934890937
# local minimum occurs at  -3.7778766934890937
# Iteration is  94
#  value is : -3.8023191596193118
# local minimum occurs at  -3.8023191596193118
# Iteration is  95
#  value is : -3.8262727764269258
# local minimum occurs at  -3.8262727764269258
# Iteration is  96
#  value is : -3.8497473208983872
# local minimum occurs at  -3.8497473208983872
# Iteration is  97
#  value is : -3.8727523744804193
# local minimum occurs at  -3.8727523744804193
# Iteration is  98
#  value is : -3.895297326990811
# local minimum occurs at  -3.895297326990811
# Iteration is  99
#  value is : -3.917391380450995
# local minimum occurs at  -3.917391380450995
# Iteration is  100
#  value is : -3.939043552841975
# local minimum occurs at  -3.939043552841975
# Iteration is  101
#  value is : -3.9602626817851356
# local minimum occurs at  -3.9602626817851356
# Iteration is  102
#  value is : -3.981057428149433
# local minimum occurs at  -3.981057428149433
# Iteration is  103
#  value is : -4.001436279586445
# local minimum occurs at  -4.001436279586445
# Iteration is  104
#  value is : -4.021407553994716
# local minimum occurs at  -4.021407553994716
# Iteration is  105
#  value is : -4.040979402914822
# local minimum occurs at  -4.040979402914822
# Iteration is  106
#  value is : -4.060159814856525
# local minimum occurs at  -4.060159814856525
# Iteration is  107
#  value is : -4.078956618559395
# local minimum occurs at  -4.078956618559395
# Iteration is  108
#  value is : -4.097377486188207
# local minimum occurs at  -4.097377486188207
# Iteration is  109
#  value is : -4.115429936464443
# local minimum occurs at  -4.115429936464443
# Iteration is  110
#  value is : -4.133121337735154
# local minimum occurs at  -4.133121337735154
# Iteration is  111
#  value is : -4.150458910980451
# local minimum occurs at  -4.150458910980451
# Iteration is  112
#  value is : -4.167449732760842
# local minimum occurs at  -4.167449732760842
# Iteration is  113
#  value is : -4.1841007381056246
# local minimum occurs at  -4.1841007381056246
# Iteration is  114
#  value is : -4.200418723343512
# local minimum occurs at  -4.200418723343512
# Iteration is  115
#  value is : -4.216410348876642
# local minimum occurs at  -4.216410348876642
# Iteration is  116
#  value is : -4.2320821418991095
# local minimum occurs at  -4.2320821418991095
# Iteration is  117
#  value is : -4.247440499061128
# local minimum occurs at  -4.247440499061128
# Iteration is  118
#  value is : -4.262491689079905
# local minimum occurs at  -4.262491689079905
# Iteration is  119
#  value is : -4.277241855298307
# local minimum occurs at  -4.277241855298307
# Iteration is  120
#  value is : -4.291697018192341
# local minimum occurs at  -4.291697018192341
# Iteration is  121
#  value is : -4.305863077828494
# local minimum occurs at  -4.305863077828494
# Iteration is  122
#  value is : -4.319745816271924
# local minimum occurs at  -4.319745816271924
# Iteration is  123
#  value is : -4.333350899946486
# local minimum occurs at  -4.333350899946486
# Iteration is  124
#  value is : -4.3466838819475555
# local minimum occurs at  -4.3466838819475555
# Iteration is  125
#  value is : -4.359750204308605
# local minimum occurs at  -4.359750204308605
# Iteration is  126
#  value is : -4.372555200222433
# local minimum occurs at  -4.372555200222433
# Iteration is  127
#  value is : -4.385104096217984
# local minimum occurs at  -4.385104096217984
# Iteration is  128
#  value is : -4.3974020142936245
# local minimum occurs at  -4.3974020142936245
# Iteration is  129
#  value is : -4.409453974007752
# local minimum occurs at  -4.409453974007752
# Iteration is  130
#  value is : -4.421264894527597
# local minimum occurs at  -4.421264894527597
# Iteration is  131
#  value is : -4.432839596637045
# local minimum occurs at  -4.432839596637045
# Iteration is  132
#  value is : -4.444182804704305
# local minimum occurs at  -4.444182804704305
# Iteration is  133
#  value is : -4.4552991486102185
# local minimum occurs at  -4.4552991486102185
# Iteration is  134
#  value is : -4.466193165638014
# local minimum occurs at  -4.466193165638014
# Iteration is  135
#  value is : -4.4768693023252535
# local minimum occurs at  -4.4768693023252535
# Iteration is  136
#  value is : -4.487331916278748
# local minimum occurs at  -4.487331916278748
# Iteration is  137
#  value is : -4.497585277953173
# local minimum occurs at  -4.497585277953173
# Iteration is  138
#  value is : -4.50763357239411
# local minimum occurs at  -4.50763357239411
# Iteration is  139
#  value is : -4.517480900946228
# local minimum occurs at  -4.517480900946228
# Iteration is  140
#  value is : -4.527131282927304
# local minimum occurs at  -4.527131282927304
# Iteration is  141
#  value is : -4.536588657268758
# local minimum occurs at  -4.536588657268758
# Iteration is  142
#  value is : -4.545856884123382
# local minimum occurs at  -4.545856884123382
# Iteration is  143
#  value is : -4.5549397464409145
# local minimum occurs at  -4.5549397464409145
# Iteration is  144
#  value is : -4.563840951512097
# local minimum occurs at  -4.563840951512097
# Iteration is  145
#  value is : -4.572564132481855
# local minimum occurs at  -4.572564132481855
# Iteration is  146
#  value is : -4.581112849832218
# local minimum occurs at  -4.581112849832218
# Iteration is  147
#  value is : -4.589490592835574
# local minimum occurs at  -4.589490592835574
# Iteration is  148
#  value is : -4.597700780978863
# local minimum occurs at  -4.597700780978863
# Iteration is  149
#  value is : -4.605746765359285
# local minimum occurs at  -4.605746765359285
# Iteration is  150
#  value is : -4.6136318300521
# local minimum occurs at  -4.6136318300521
# Iteration is  151
#  value is : -4.621359193451058
# local minimum occurs at  -4.621359193451058
# Iteration is  152
#  value is : -4.628932009582036
# local minimum occurs at  -4.628932009582036
# Iteration is  153
#  value is : -4.636353369390395
# local minimum occurs at  -4.636353369390395
# Iteration is  154
#  value is : -4.643626302002588
# local minimum occurs at  -4.643626302002588
# Iteration is  155
#  value is : -4.650753775962536
# local minimum occurs at  -4.650753775962536
# Iteration is  156
#  value is : -4.657738700443285
# local minimum occurs at  -4.657738700443285
# Iteration is  157
#  value is : -4.664583926434419
# local minimum occurs at  -4.664583926434419
# Iteration is  158
#  value is : -4.671292247905731
# local minimum occurs at  -4.671292247905731
# Iteration is  159
#  value is : -4.6778664029476165
# local minimum occurs at  -4.6778664029476165
# Iteration is  160
#  value is : -4.684309074888664
# local minimum occurs at  -4.684309074888664
# Iteration is  161
#  value is : -4.6906228933908904
# local minimum occurs at  -4.6906228933908904
# Iteration is  162
#  value is : -4.696810435523073
# local minimum occurs at  -4.696810435523073
# Iteration is  163
#  value is : -4.702874226812612
# local minimum occurs at  -4.702874226812612
# Iteration is  164
#  value is : -4.708816742276359
# local minimum occurs at  -4.708816742276359
# Iteration is  165
#  value is : -4.714640407430832
# local minimum occurs at  -4.714640407430832
# Iteration is  166
#  value is : -4.720347599282215
# local minimum occurs at  -4.720347599282215
# Iteration is  167
#  value is : -4.725940647296571
# local minimum occurs at  -4.725940647296571
# Iteration is  168
#  value is : -4.731421834350639
# local minimum occurs at  -4.731421834350639
# Iteration is  169
#  value is : -4.736793397663627
# local minimum occurs at  -4.736793397663627
# Iteration is  170
#  value is : -4.742057529710355
# local minimum occurs at  -4.742057529710355
# Iteration is  171
#  value is : -4.747216379116147
# local minimum occurs at  -4.747216379116147
# Iteration is  172
#  value is : -4.752272051533824
# local minimum occurs at  -4.752272051533824
# Iteration is  173
#  value is : -4.757226610503148
# local minimum occurs at  -4.757226610503148
# Iteration is  174
#  value is : -4.762082078293084
# local minimum occurs at  -4.762082078293084
# Iteration is  175
#  value is : -4.766840436727223
# local minimum occurs at  -4.766840436727223
# Iteration is  176
#  value is : -4.771503627992678
# local minimum occurs at  -4.771503627992678
# Iteration is  177
#  value is : -4.776073555432824
# local minimum occurs at  -4.776073555432824
# Iteration is  178
#  value is : -4.780552084324168
# local minimum occurs at  -4.780552084324168
# Iteration is  179
#  value is : -4.784941042637685
# local minimum occurs at  -4.784941042637685
# Iteration is  180
#  value is : -4.7892422217849315
# local minimum occurs at  -4.7892422217849315
# Iteration is  181
#  value is : -4.793457377349233
# local minimum occurs at  -4.793457377349233
# Iteration is  182
#  value is : -4.7975882298022485
# local minimum occurs at  -4.7975882298022485
# Iteration is  183
#  value is : -4.801636465206204
# local minimum occurs at  -4.801636465206204
# Iteration is  184
#  value is : -4.805603735902079
# local minimum occurs at  -4.805603735902079
# Iteration is  185
#  value is : -4.809491661184038
# local minimum occurs at  -4.809491661184038
# Iteration is  186
#  value is : -4.813301827960357
# local minimum occurs at  -4.813301827960357
# Iteration is  187
#  value is : -4.81703579140115
# local minimum occurs at  -4.81703579140115
# Iteration is  188
#  value is : -4.820695075573127
# local minimum occurs at  -4.820695075573127
# Iteration is  189
#  value is : -4.824281174061665
# local minimum occurs at  -4.824281174061665
# Iteration is  190
#  value is : -4.827795550580431
# local minimum occurs at  -4.827795550580431
# Iteration is  191
#  value is : -4.831239639568823
# local minimum occurs at  -4.831239639568823
# Iteration is  192
#  value is : -4.834614846777447
# local minimum occurs at  -4.834614846777447
# Iteration is  193
#  value is : -4.837922549841898
# local minimum occurs at  -4.837922549841898
# Iteration is  194
#  value is : -4.84116409884506
# local minimum occurs at  -4.84116409884506
# Iteration is  195
#  value is : -4.844340816868159
# local minimum occurs at  -4.844340816868159
# Iteration is  196
#  value is : -4.847454000530796
# local minimum occurs at  -4.847454000530796
# Iteration is  197
#  value is : -4.85050492052018
# local minimum occurs at  -4.85050492052018
# Iteration is  198
#  value is : -4.853494822109776
# local minimum occurs at  -4.853494822109776
# Iteration is  199
#  value is : -4.85642492566758
# local minimum occurs at  -4.85642492566758
# Iteration is  200
#  value is : -4.859296427154229
# local minimum occurs at  -4.859296427154229
# Iteration is  201
#  value is : -4.862110498611145
# local minimum occurs at  -4.862110498611145
# Iteration is  202
#  value is : -4.864868288638922
# local minimum occurs at  -4.864868288638922
# Iteration is  203
#  value is : -4.867570922866143
# local minimum occurs at  -4.867570922866143
# Iteration is  204
#  value is : -4.87021950440882
# local minimum occurs at  -4.87021950440882
# Iteration is  205
#  value is : -4.872815114320644
# local minimum occurs at  -4.872815114320644
# Iteration is  206
#  value is : -4.875358812034231
# local minimum occurs at  -4.875358812034231
# Iteration is  207
#  value is : -4.877851635793546
# local minimum occurs at  -4.877851635793546
# Iteration is  208
#  value is : -4.880294603077676
# local minimum occurs at  -4.880294603077676
# Iteration is  209
#  value is : -4.882688711016122
# local minimum occurs at  -4.882688711016122
# Iteration is  210
#  value is : -4.8850349367958
# local minimum occurs at  -4.8850349367958
# Iteration is  211
#  value is : -4.887334238059884
# local minimum occurs at  -4.887334238059884
# Iteration is  212
#  value is : -4.8895875532986866
# local minimum occurs at  -4.8895875532986866
# Iteration is  213
#  value is : -4.891795802232712
# local minimum occurs at  -4.891795802232712
# Iteration is  214
#  value is : -4.893959886188058
# local minimum occurs at  -4.893959886188058
# Iteration is  215
#  value is : -4.896080688464297
# local minimum occurs at  -4.896080688464297
# Iteration is  216
#  value is : -4.898159074695011
# local minimum occurs at  -4.898159074695011
# Iteration is  217
#  value is : -4.9001958932011105
# local minimum occurs at  -4.9001958932011105
# Iteration is  218
#  value is : -4.902191975337089
# local minimum occurs at  -4.902191975337089
# Iteration is  219
#  value is : -4.904148135830347
# local minimum occurs at  -4.904148135830347
# Iteration is  220
#  value is : -4.90606517311374
# local minimum occurs at  -4.90606517311374
# Iteration is  221
#  value is : -4.907943869651465
# local minimum occurs at  -4.907943869651465
# Iteration is  222
#  value is : -4.909784992258436
# local minimum occurs at  -4.909784992258436
# Iteration is  223
#  value is : -4.911589292413267
# local minimum occurs at  -4.911589292413267
# Iteration is  224
#  value is : -4.913357506565002
# local minimum occurs at  -4.913357506565002
# Iteration is  225
#  value is : -4.915090356433702
# local minimum occurs at  -4.915090356433702
# Iteration is  226
#  value is : -4.9167885493050285
# local minimum occurs at  -4.9167885493050285
# Iteration is  227
#  value is : -4.918452778318928
# local minimum occurs at  -4.918452778318928
# Iteration is  228
#  value is : -4.920083722752549
# local minimum occurs at  -4.920083722752549
# Iteration is  229
#  value is : -4.921682048297498
# local minimum occurs at  -4.921682048297498
# Iteration is  230
#  value is : -4.923248407331548
# local minimum occurs at  -4.923248407331548
# Iteration is  231
#  value is : -4.9247834391849175
# local minimum occurs at  -4.9247834391849175
# Iteration is  232
#  value is : -4.926287770401219
# local minimum occurs at  -4.926287770401219
# Iteration is  233
#  value is : -4.927762014993195
# local minimum occurs at  -4.927762014993195
# Iteration is  234
#  value is : -4.929206774693331
# local minimum occurs at  -4.929206774693331
# Iteration is  235
#  value is : -4.930622639199464
# local minimum occurs at  -4.930622639199464
# Iteration is  236
#  value is : -4.932010186415474
# local minimum occurs at  -4.932010186415474
# Iteration is  237
#  value is : -4.933369982687164
# local minimum occurs at  -4.933369982687164
# Iteration is  238
#  value is : -4.934702583033421
# local minimum occurs at  -4.934702583033421
# Iteration is  239
#  value is : -4.936008531372753
# local minimum occurs at  -4.936008531372753
# Iteration is  240
#  value is : -4.937288360745298
# local minimum occurs at  -4.937288360745298
# Iteration is  241
#  value is : -4.938542593530392
# local minimum occurs at  -4.938542593530392
# Iteration is  242
#  value is : -4.939771741659784
# local minimum occurs at  -4.939771741659784
# Iteration is  243
#  value is : -4.940976306826588
# local minimum occurs at  -4.940976306826588
# Iteration is  244
#  value is : -4.942156780690056
# local minimum occurs at  -4.942156780690056
# Iteration is  245
#  value is : -4.943313645076255
# local minimum occurs at  -4.943313645076255
# Iteration is  246
#  value is : -4.94444737217473
# local minimum occurs at  -4.94444737217473
# Iteration is  247
#  value is : -4.945558424731236
# local minimum occurs at  -4.945558424731236
# Iteration is  248
#  value is : -4.946647256236611
# local minimum occurs at  -4.946647256236611
# Iteration is  249
#  value is : -4.947714311111879
# local minimum occurs at  -4.947714311111879
# Iteration is  250
#  value is : -4.9487600248896415
# local minimum occurs at  -4.9487600248896415
# Iteration is  251
#  value is : -4.949784824391848
# local minimum occurs at  -4.949784824391848
# Iteration is  252
#  value is : -4.950789127904011
# local minimum occurs at  -4.950789127904011
# Iteration is  253
#  value is : -4.951773345345931
# local minimum occurs at  -4.951773345345931
# Iteration is  254
#  value is : -4.952737878439012
# local minimum occurs at  -4.952737878439012
# Iteration is  255
#  value is : -4.953683120870232
# local minimum occurs at  -4.953683120870232
# Iteration is  256
#  value is : -4.954609458452827
# local minimum occurs at  -4.954609458452827
# Iteration is  257
#  value is : -4.955517269283771
# local minimum occurs at  -4.955517269283771
# Iteration is  258
#  value is : -4.956406923898095
# local minimum occurs at  -4.956406923898095
# Iteration is  259
#  value is : -4.957278785420133
# local minimum occurs at  -4.957278785420133
# Iteration is  260
#  value is : -4.958133209711731
# local minimum occurs at  -4.958133209711731
# Iteration is  261
#  value is : -4.958970545517496
# local minimum occurs at  -4.958970545517496
# Iteration is  262
#  value is : -4.959791134607146
# local minimum occurs at  -4.959791134607146
# Iteration is  263
#  value is : -4.960595311915003
# local minimum occurs at  -4.960595311915003
# Iteration is  264
#  value is : -4.9613834056767026
# local minimum occurs at  -4.9613834056767026
# Iteration is  265
#  value is : -4.962155737563169
# local minimum occurs at  -4.962155737563169
# Iteration is  266
#  value is : -4.962912622811905
# local minimum occurs at  -4.962912622811905
# Iteration is  267
#  value is : -4.963654370355667
# local minimum occurs at  -4.963654370355667
# Iteration is  268
#  value is : -4.964381282948554
# local minimum occurs at  -4.964381282948554
# Iteration is  269
#  value is : -4.965093657289583
# local minimum occurs at  -4.965093657289583
# Iteration is  270
#  value is : -4.965791784143791
# local minimum occurs at  -4.965791784143791
# Iteration is  271
#  value is : -4.966475948460915
# local minimum occurs at  -4.966475948460915
# Iteration is  272
#  value is : -4.967146429491697
# local minimum occurs at  -4.967146429491697
# Iteration is  273
#  value is : -4.967803500901863
# local minimum occurs at  -4.967803500901863
# Iteration is  274
#  value is : -4.968447430883826
# local minimum occurs at  -4.968447430883826
# Iteration is  275
#  value is : -4.969078482266149
# local minimum occurs at  -4.969078482266149
# Iteration is  276
#  value is : -4.969696912620826
# local minimum occurs at  -4.969696912620826
# Iteration is  277
#  value is : -4.970302974368409
# local minimum occurs at  -4.970302974368409
# Iteration is  278
#  value is : -4.970896914881041
# local minimum occurs at  -4.970896914881041
# Iteration is  279
#  value is : -4.97147897658342
# local minimum occurs at  -4.97147897658342
# Iteration is  280
#  value is : -4.972049397051752
# local minimum occurs at  -4.972049397051752
# Iteration is  281
#  value is : -4.972608409110717
# local minimum occurs at  -4.972608409110717
# Iteration is  282
#  value is : -4.973156240928502
# local minimum occurs at  -4.973156240928502
# Iteration is  283
#  value is : -4.973693116109932
# local minimum occurs at  -4.973693116109932
# Iteration is  284
#  value is : -4.974219253787734
# local minimum occurs at  -4.974219253787734
# Iteration is  285
#  value is : -4.974734868711979
# local minimum occurs at  -4.974734868711979
# Iteration is  286
#  value is : -4.975240171337739
# local minimum occurs at  -4.975240171337739
# Iteration is  287
#  value is : -4.975735367910985
# local minimum occurs at  -4.975735367910985
# Iteration is  288
#  value is : -4.976220660552765
# local minimum occurs at  -4.976220660552765
# Iteration is  289
#  value is : -4.976696247341709
# local minimum occurs at  -4.976696247341709
# Iteration is  290
#  value is : -4.977162322394875
# local minimum occurs at  -4.977162322394875
# Iteration is  291
#  value is : -4.977619075946977
# local minimum occurs at  -4.977619075946977
# Iteration is  292
#  value is : -4.978066694428038
# local minimum occurs at  -4.978066694428038
# Iteration is  293
#  value is : -4.978505360539477
# local minimum occurs at  -4.978505360539477
# Iteration is  294
#  value is : -4.978935253328687
# local minimum occurs at  -4.978935253328687
# Iteration is  295
#  value is : -4.979356548262113
# local minimum occurs at  -4.979356548262113
# Iteration is  296
#  value is : -4.979769417296871
# local minimum occurs at  -4.979769417296871
# Iteration is  297
#  value is : -4.980174028950934
# local minimum occurs at  -4.980174028950934
# Iteration is  298
#  value is : -4.980570548371915
# local minimum occurs at  -4.980570548371915
# Iteration is  299
#  value is : -4.980959137404477
# local minimum occurs at  -4.980959137404477
# Iteration is  300
#  value is : -4.981339954656387
# local minimum occurs at  -4.981339954656387
# Iteration is  301
#  value is : -4.981713155563259
# local minimum occurs at  -4.981713155563259
# Iteration is  302
#  value is : -4.982078892451994
# local minimum occurs at  -4.982078892451994
# Iteration is  303
#  value is : -4.9824373146029535
# local minimum occurs at  -4.9824373146029535
# Iteration is  304
#  value is : -4.982788568310895
# local minimum occurs at  -4.982788568310895
# Iteration is  305
#  value is : -4.983132796944677
# local minimum occurs at  -4.983132796944677
# Iteration is  306
#  value is : -4.983470141005784
# local minimum occurs at  -4.983470141005784
# Iteration is  307
#  value is : -4.983800738185668
# local minimum occurs at  -4.983800738185668
# Iteration is  308
#  value is : -4.984124723421955
# local minimum occurs at  -4.984124723421955
# Iteration is  309
#  value is : -4.984442228953515
# local minimum occurs at  -4.984442228953515
# Iteration is  310
#  value is : -4.984753384374445
# local minimum occurs at  -4.984753384374445
# Iteration is  311
#  value is : -4.985058316686956
# local minimum occurs at  -4.985058316686956
# Iteration is  312
#  value is : -4.9853571503532175
# local minimum occurs at  -4.9853571503532175
# Iteration is  313
#  value is : -4.985650007346153
# local minimum occurs at  -4.985650007346153
# Iteration is  314
#  value is : -4.9859370071992295
# local minimum occurs at  -4.9859370071992295
# Iteration is  315
#  value is : -4.986218267055245
# local minimum occurs at  -4.986218267055245
# Iteration is  316
#  value is : -4.98649390171414
# local minimum occurs at  -4.98649390171414
# Iteration is  317
#  value is : -4.986764023679857
# local minimum occurs at  -4.986764023679857
# Iteration is  318
#  value is : -4.98702874320626
# local minimum occurs at  -4.98702874320626
# Iteration is  319
#  value is : -4.987288168342134
# local minimum occurs at  -4.987288168342134
# Iteration is  320
#  value is : -4.987542404975292
# local minimum occurs at  -4.987542404975292
# Iteration is  321
#  value is : -4.987791556875786
# local minimum occurs at  -4.987791556875786
# Iteration is  322
#  value is : -4.98803572573827
# local minimum occurs at  -4.98803572573827
# Iteration is  323
#  value is : -4.988275011223505
# local minimum occurs at  -4.988275011223505
# Iteration is  324
#  value is : -4.988509510999035
# local minimum occurs at  -4.988509510999035
# Iteration is  325
#  value is : -4.988739320779054
# local minimum occurs at  -4.988739320779054
# Iteration is  326
#  value is : -4.988964534363473
# local minimum occurs at  -4.988964534363473
# Iteration is  327
#  value is : -4.989185243676204
# local minimum occurs at  -4.989185243676204
# Iteration is  328
#  value is : -4.98940153880268
# local minimum occurs at  -4.98940153880268
# Iteration is  329
#  value is : -4.989613508026626
# local minimum occurs at  -4.989613508026626
# Iteration is  330
#  value is : -4.989821237866094
# local minimum occurs at  -4.989821237866094
# Iteration is  331
#  value is : -4.990024813108772
# local minimum occurs at  -4.990024813108772
# Iteration is  332
#  value is : -4.9902243168465965
# local minimum occurs at  -4.9902243168465965
# Iteration is  333
#  value is : -4.990419830509665
# local minimum occurs at  -4.990419830509665
# Iteration is  334
#  value is : -4.990611433899471
# local minimum occurs at  -4.990611433899471
# Iteration is  335
#  value is : -4.990799205221482
# local minimum occurs at  -4.990799205221482
# Iteration is  336
#  value is : -4.990983221117052
# local minimum occurs at  -4.990983221117052
# Iteration is  337
#  value is : -4.991163556694711
# local minimum occurs at  -4.991163556694711
# Iteration is  338
#  value is : -4.991340285560817
# local minimum occurs at  -4.991340285560817
# Iteration is  339
#  value is : -4.9915134798496
# local minimum occurs at  -4.9915134798496
# Iteration is  340
#  value is : -4.991683210252608
# local minimum occurs at  -4.991683210252608
# Iteration is  341
#  value is : -4.991849546047556
# local minimum occurs at  -4.991849546047556
# Iteration is  342
#  value is : -4.992012555126605
# local minimum occurs at  -4.992012555126605
# Iteration is  343
#  value is : -4.992172304024073
# local minimum occurs at  -4.992172304024073
# Iteration is  344
#  value is : -4.992328857943591
# local minimum occurs at  -4.992328857943591
# Iteration is  345
#  value is : -4.99248228078472
# local minimum occurs at  -4.99248228078472
# Iteration is  346
#  value is : -4.992632635169025
# local minimum occurs at  -4.992632635169025
# Iteration is  347
#  value is : -4.9927799824656445
# local minimum occurs at  -4.9927799824656445
# Iteration is  348
#  value is : -4.992924382816332
# local minimum occurs at  -4.992924382816332
# Iteration is  349
#  value is : -4.993065895160005
# local minimum occurs at  -4.993065895160005
# Iteration is  350
#  value is : -4.993204577256805
# local minimum occurs at  -4.993204577256805
# Iteration is  351
#  value is : -4.993340485711669
# local minimum occurs at  -4.993340485711669
# Iteration is  352
#  value is : -4.993473675997436
# local minimum occurs at  -4.993473675997436
# Iteration is  353
#  value is : -4.993604202477487
# local minimum occurs at  -4.993604202477487
# Iteration is  354
#  value is : -4.993732118427937
# local minimum occurs at  -4.993732118427937
# Iteration is  355
#  value is : -4.993857476059379
# local minimum occurs at  -4.993857476059379
# Iteration is  356
#  value is : -4.993980326538191
# local minimum occurs at  -4.993980326538191
# Iteration is  357
#  value is : -4.9941007200074266
# local minimum occurs at  -4.9941007200074266
# Iteration is  358
#  value is : -4.994218705607278
# local minimum occurs at  -4.994218705607278
# Iteration is  359
#  value is : -4.994334331495133
# local minimum occurs at  -4.994334331495133
# Iteration is  360
#  value is : -4.994447644865231
# local minimum occurs at  -4.994447644865231
# Iteration is  361
#  value is : -4.994558691967926
# local minimum occurs at  -4.994558691967926
# Iteration is  362
#  value is : -4.994667518128567
# local minimum occurs at  -4.994667518128567
# Iteration is  363
#  value is : -4.994774167765996
# local minimum occurs at  -4.994774167765996
# Iteration is  364
#  value is : -4.9948786844106765
# local minimum occurs at  -4.9948786844106765
# Iteration is  365
#  value is : -4.994981110722463
# local minimum occurs at  -4.994981110722463
# Iteration is  366
#  value is : -4.995081488508014
# local minimum occurs at  -4.995081488508014
# Iteration is  367
#  value is : -4.995179858737854
# local minimum occurs at  -4.995179858737854
# Iteration is  368
#  value is : -4.995276261563097
# local minimum occurs at  -4.995276261563097
# Iteration is  369
#  value is : -4.995370736331835
# local minimum occurs at  -4.995370736331835
# Iteration is  370
#  value is : -4.9954633216051985
# local minimum occurs at  -4.9954633216051985
# Iteration is  371
#  value is : -4.995554055173095
# local minimum occurs at  -4.995554055173095
# Iteration is  372
#  value is : -4.995642974069633
# local minimum occurs at  -4.995642974069633
# Iteration is  373
#  value is : -4.99573011458824
# local minimum occurs at  -4.99573011458824
# Iteration is  374
#  value is : -4.995815512296476
# local minimum occurs at  -4.995815512296476
# Iteration is  375
#  value is : -4.995899202050547
# local minimum occurs at  -4.995899202050547
# Iteration is  376
#  value is : -4.995981218009535
# local minimum occurs at  -4.995981218009535
# Iteration is  377
#  value is : -4.996061593649345
# local minimum occurs at  -4.996061593649345
# Iteration is  378
#  value is : -4.996140361776358
# local minimum occurs at  -4.996140361776358
# Iteration is  379
#  value is : -4.996217554540831
# local minimum occurs at  -4.996217554540831
# Iteration is  380
#  value is : -4.996293203450014
# local minimum occurs at  -4.996293203450014
# Iteration is  381
#  value is : -4.996367339381013
# local minimum occurs at  -4.996367339381013
# Iteration is  382
#  value is : -4.996439992593393
# local minimum occurs at  -4.996439992593393
# Iteration is  383
#  value is : -4.996511192741525
# local minimum occurs at  -4.996511192741525
# Iteration is  384
#  value is : -4.996580968886694
# local minimum occurs at  -4.996580968886694
# Iteration is  385
#  value is : -4.99664934950896
# local minimum occurs at  -4.99664934950896
# Iteration is  386
#  value is : -4.9967163625187805
# local minimum occurs at  -4.9967163625187805
# Iteration is  387
#  value is : -4.996782035268405
# local minimum occurs at  -4.996782035268405
# Iteration is  388
#  value is : -4.996846394563037
# local minimum occurs at  -4.996846394563037
# Iteration is  389
#  value is : -4.996909466671776
# local minimum occurs at  -4.996909466671776
# Iteration is  390
#  value is : -4.996971277338341
# local minimum occurs at  -4.996971277338341
# Iteration is  391
#  value is : -4.997031851791574
# local minimum occurs at  -4.997031851791574
# Iteration is  392
#  value is : -4.997091214755742
# local minimum occurs at  -4.997091214755742
# Iteration is  393
#  value is : -4.997149390460628
# local minimum occurs at  -4.997149390460628
# Iteration is  394
#  value is : -4.997206402651415
# local minimum occurs at  -4.997206402651415
# Iteration is  395
#  value is : -4.997262274598387
# local minimum occurs at  -4.997262274598387
# Iteration is  396
#  value is : -4.997317029106419
# local minimum occurs at  -4.997317029106419
# Iteration is  397
#  value is : -4.997370688524291
# local minimum occurs at  -4.997370688524291
# Iteration is  398
#  value is : -4.997423274753805
# local minimum occurs at  -4.997423274753805
# Iteration is  399
#  value is : -4.997474809258729
# local minimum occurs at  -4.997474809258729
# Iteration is  400
#  value is : -4.997525313073554
# local minimum occurs at  -4.997525313073554
# Iteration is  401
#  value is : -4.997574806812083
# local minimum occurs at  -4.997574806812083
# Iteration is  402
#  value is : -4.997623310675841
# local minimum occurs at  -4.997623310675841
# Iteration is  403
#  value is : -4.997670844462324
# local minimum occurs at  -4.997670844462324
# Iteration is  404
#  value is : -4.997717427573078
# local minimum occurs at  -4.997717427573078
# Iteration is  405
#  value is : -4.997763079021617
# local minimum occurs at  -4.997763079021617
# Iteration is  406
#  value is : -4.997807817441185
# local minimum occurs at  -4.997807817441185
# Iteration is  407
#  value is : -4.997851661092361
# local minimum occurs at  -4.997851661092361
# Iteration is  408
#  value is : -4.997894627870514
# local minimum occurs at  -4.997894627870514
# Iteration is  409
#  value is : -4.997936735313104
# local minimum occurs at  -4.997936735313104
# Iteration is  410
#  value is : -4.9979780006068415
# local minimum occurs at  -4.9979780006068415
# Iteration is  411
#  value is : -4.998018440594705
# local minimum occurs at  -4.998018440594705
# Iteration is  412
#  value is : -4.998058071782811
# local minimum occurs at  -4.998058071782811
# Iteration is  413
#  value is : -4.998096910347155
# local minimum occurs at  -4.998096910347155
# Iteration is  414
#  value is : -4.998134972140212
# local minimum occurs at  -4.998134972140212
# Iteration is  415
#  value is : -4.998172272697408
# local minimum occurs at  -4.998172272697408
# Iteration is  416
#  value is : -4.9982088272434595
# local minimum occurs at  -4.9982088272434595
# Iteration is  417
#  value is : -4.998244650698591
# local minimum occurs at  -4.998244650698591
# Iteration is  418
#  value is : -4.998279757684619
# local minimum occurs at  -4.998279757684619
# Iteration is  419
#  value is : -4.998314162530927
# local minimum occurs at  -4.998314162530927
# Iteration is  420
#  value is : -4.998347879280309
# local minimum occurs at  -4.998347879280309
# Iteration is  421
#  value is : -4.998380921694703
# local minimum occurs at  -4.998380921694703
# Iteration is  422
#  value is : -4.998413303260809
# local minimum occurs at  -4.998413303260809
# Iteration is  423
#  value is : -4.998445037195593
# local minimum occurs at  -4.998445037195593
# Iteration is  424
#  value is : -4.998476136451681
# local minimum occurs at  -4.998476136451681
# Iteration is  425
#  value is : -4.998506613722648
# local minimum occurs at  -4.998506613722648
# Iteration is  426
#  value is : -4.998536481448195
# local minimum occurs at  -4.998536481448195
# Iteration is  427
#  value is : -4.998565751819231
# local minimum occurs at  -4.998565751819231
# Iteration is  428
#  value is : -4.998594436782846
# local minimum occurs at  -4.998594436782846
# Iteration is  429
#  value is : -4.998622548047189
# local minimum occurs at  -4.998622548047189
# Iteration is  430
#  value is : -4.998650097086245
# local minimum occurs at  -4.998650097086245
# Iteration is  431
#  value is : -4.9986770951445205
# local minimum occurs at  -4.9986770951445205
# Iteration is  432
#  value is : -4.99870355324163
# local minimum occurs at  -4.99870355324163
# Iteration is  433
#  value is : -4.998729482176797
# local minimum occurs at  -4.998729482176797
# Iteration is  434
#  value is : -4.998754892533261
# local minimum occurs at  -4.998754892533261
# Iteration is  435
#  value is : -4.998779794682596
# local minimum occurs at  -4.998779794682596
# Iteration is  436
#  value is : -4.998804198788944
# local minimum occurs at  -4.998804198788944
# Iteration is  437
#  value is : -4.998828114813166
# local minimum occurs at  -4.998828114813166
# Iteration is  438
#  value is : -4.998851552516903
# local minimum occurs at  -4.998851552516903
# Iteration is  439
#  value is : -4.998874521466565
# local minimum occurs at  -4.998874521466565
# Iteration is  440
#  value is : -4.998897031037234
# local minimum occurs at  -4.998897031037234
# Iteration is  441
#  value is : -4.998919090416489
# local minimum occurs at  -4.998919090416489
# Iteration is  442
#  value is : -4.99894070860816
# local minimum occurs at  -4.99894070860816
# Iteration is  443
#  value is : -4.998961894435997
# local minimum occurs at  -4.998961894435997
# Iteration is  444
#  value is : -4.998982656547277
# local minimum occurs at  -4.998982656547277
# Iteration is  445
#  value is : -4.999003003416331
# local minimum occurs at  -4.999003003416331
# Iteration is  446
#  value is : -4.999022943348004
# local minimum occurs at  -4.999022943348004
# Iteration is  447
#  value is : -4.999042484481044
# local minimum occurs at  -4.999042484481044
# Iteration is  448
#  value is : -4.999061634791423
# local minimum occurs at  -4.999061634791423
# Iteration is  449
#  value is : -4.999080402095594
# local minimum occurs at  -4.999080402095594
# Iteration is  450
#  value is : -4.999098794053682
# local minimum occurs at  -4.999098794053682
# Iteration is  451
#  value is : -4.999116818172609
# local minimum occurs at  -4.999116818172609
# Iteration is  452
#  value is : -4.999134481809157
# local minimum occurs at  -4.999134481809157
# Iteration is  453
#  value is : -4.999151792172974
# local minimum occurs at  -4.999151792172974
# Iteration is  454
#  value is : -4.999168756329515
# local minimum occurs at  -4.999168756329515
# Iteration is  455
#  value is : -4.999185381202924
# local minimum occurs at  -4.999185381202924
# Iteration is  456
#  value is : -4.999201673578866
# local minimum occurs at  -4.999201673578866
# Iteration is  457
#  value is : -4.999217640107289
# local minimum occurs at  -4.999217640107289
# Iteration is  458
#  value is : -4.999233287305143
# local minimum occurs at  -4.999233287305143
# Iteration is  459
#  value is : -4.9992486215590395
# local minimum occurs at  -4.9992486215590395
# Iteration is  460
#  value is : -4.999263649127859
# local minimum occurs at  -4.999263649127859
# Iteration is  461
#  value is : -4.999278376145302
# local minimum occurs at  -4.999278376145302
# Iteration is  462
#  value is : -4.999292808622396
# local minimum occurs at  -4.999292808622396
# Iteration is  463
#  value is : -4.999306952449948
# local minimum occurs at  -4.999306952449948
# Iteration is  464
#  value is : -4.999320813400949
# local minimum occurs at  -4.999320813400949
# Iteration is  465
#  value is : -4.99933439713293
# local minimum occurs at  -4.99933439713293
# Iteration is  466
#  value is : -4.999347709190272
# local minimum occurs at  -4.999347709190272
# Iteration is  467
#  value is : -4.9993607550064665
# local minimum occurs at  -4.9993607550064665
# Iteration is  468
#  value is : -4.999373539906337
# local minimum occurs at  -4.999373539906337
# Iteration is  469
#  value is : -4.99938606910821
# local minimum occurs at  -4.99938606910821
# Iteration is  470
#  value is : -4.9993983477260455
# local minimum occurs at  -4.9993983477260455
# Iteration is  471
#  value is : -4.999410380771525
# local minimum occurs at  -4.999410380771525
# Iteration is  472
#  value is : -4.999422173156094
# local minimum occurs at  -4.999422173156094
# Iteration is  473
#  value is : -4.9994337296929725
# local minimum occurs at  -4.9994337296929725
# Iteration is  474
#  value is : -4.999445055099113
# local minimum occurs at  -4.999445055099113
# Iteration is  475
#  value is : -4.999456153997131
# local minimum occurs at  -4.999456153997131
# Iteration is  476
#  value is : -4.999467030917188
# local minimum occurs at  -4.999467030917188
# Iteration is  477
#  value is : -4.9994776902988445
# local minimum occurs at  -4.9994776902988445
# Iteration is  478
#  value is : -4.999488136492867
# local minimum occurs at  -4.999488136492867
# Iteration is  479
#  value is : -4.99949837376301
# local minimum occurs at  -4.99949837376301
# Iteration is  480
#  value is : -4.99950840628775
# local minimum occurs at  -4.99950840628775
# Iteration is  481
#  value is : -4.999518238161995
# local minimum occurs at  -4.999518238161995
# Iteration is  482
#  value is : -4.999527873398756
# local minimum occurs at  -4.999527873398756
# Iteration is  483
#  value is : -4.99953731593078
# local minimum occurs at  -4.99953731593078
# Iteration is  484
#  value is : -4.999546569612165
# local minimum occurs at  -4.999546569612165
# Iteration is  485
#  value is : -4.999555638219921
# local minimum occurs at  -4.999555638219921
# Iteration is  486
#  value is : -4.999564525455523
# local minimum occurs at  -4.999564525455523
# Iteration is  487
#  value is : -4.999573234946412
# local minimum occurs at  -4.999573234946412
# Iteration is  488
#  value is : -4.9995817702474845
# local minimum occurs at  -4.9995817702474845
# Iteration is  489
#  value is : -4.999590134842535
# local minimum occurs at  -4.999590134842535
# Iteration is  490
#  value is : -4.999598332145684
# local minimum occurs at  -4.999598332145684
# Iteration is  491
#  value is : -4.99960636550277
# local minimum occurs at  -4.99960636550277
# Iteration is  492
#  value is : -4.999614238192715
# local minimum occurs at  -4.999614238192715
# Iteration is  493
#  value is : -4.999621953428861
# local minimum occurs at  -4.999621953428861
# Iteration is  494
#  value is : -4.999629514360284
# local minimum occurs at  -4.999629514360284
# Iteration is  495
#  value is : -4.999636924073078
# local minimum occurs at  -4.999636924073078
# Iteration is  496
#  value is : -4.999644185591617
# local minimum occurs at  -4.999644185591617
# Iteration is  497
#  value is : -4.999651301879784
# local minimum occurs at  -4.999651301879784
# Iteration is  498
#  value is : -4.999658275842188
# local minimum occurs at  -4.999658275842188
# Iteration is  499
#  value is : -4.999665110325345
# local minimum occurs at  -4.999665110325345
# Iteration is  500
#  value is : -4.999671808118838
# local minimum occurs at  -4.999671808118838
# Iteration is  501
#  value is : -4.9996783719564615
# local minimum occurs at  -4.9996783719564615
# Iteration is  502
#  value is : -4.999684804517332
# local minimum occurs at  -4.999684804517332
# Iteration is  503
#  value is : -4.999691108426985
# local minimum occurs at  -4.999691108426985
# Iteration is  504
#  value is : -4.999697286258446
# local minimum occurs at  -4.999697286258446
# Iteration is  505
#  value is : -4.9997033405332765
# local minimum occurs at  -4.9997033405332765
# Iteration is  506
#  value is : -4.999709273722611
# local minimum occurs at  -4.999709273722611
# Iteration is  507
#  value is : -4.999715088248159
# local minimum occurs at  -4.999715088248159
# Iteration is  508
#  value is : -4.999720786483196
# local minimum occurs at  -4.999720786483196
# Iteration is  509
#  value is : -4.999726370753532
# local minimum occurs at  -4.999726370753532
# Iteration is  510
#  value is : -4.999731843338461
# local minimum occurs at  -4.999731843338461
# Iteration is  511
#  value is : -4.999737206471692
# local minimum occurs at  -4.999737206471692
# Iteration is  512
#  value is : -4.999742462342258
# local minimum occurs at  -4.999742462342258
# Iteration is  513
#  value is : -4.999747613095413
# local minimum occurs at  -4.999747613095413
# Iteration is  514
#  value is : -4.999752660833504
# local minimum occurs at  -4.999752660833504
# Iteration is  515
#  value is : -4.999757607616834
# local minimum occurs at  -4.999757607616834
# Iteration is  516
#  value is : -4.999762455464498
# local minimum occurs at  -4.999762455464498
# Iteration is  517
#  value is : -4.999767206355208
# local minimum occurs at  -4.999767206355208
# Iteration is  518
#  value is : -4.999771862228104
# local minimum occurs at  -4.999771862228104
# Iteration is  519
#  value is : -4.999776424983542
# local minimum occurs at  -4.999776424983542
# Iteration is  520
#  value is : -4.9997808964838715
# local minimum occurs at  -4.9997808964838715
# Iteration is  521
#  value is : -4.999785278554194
# local minimum occurs at  -4.999785278554194
# Iteration is  522
#  value is : -4.9997895729831106
# local minimum occurs at  -4.9997895729831106
# Iteration is  523
#  value is : -4.999793781523448
# local minimum occurs at  -4.999793781523448
# Iteration is  524
#  value is : -4.999797905892979
# local minimum occurs at  -4.999797905892979
# Iteration is  525
#  value is : -4.999801947775119
# local minimum occurs at  -4.999801947775119
# Iteration is  526
#  value is : -4.999805908819617
# local minimum occurs at  -4.999805908819617
# Iteration is  527
#  value is : -4.999809790643225
# local minimum occurs at  -4.999809790643225
# Iteration is  528
#  value is : -4.99981359483036
# local minimum occurs at  -4.99981359483036
# Iteration is  529
#  value is : -4.999817322933753
# local minimum occurs at  -4.999817322933753
# Iteration is  530
#  value is : -4.999820976475077
# local minimum occurs at  -4.999820976475077
# Iteration is  531
#  value is : -4.999824556945576
# local minimum occurs at  -4.999824556945576
# Iteration is  532
#  value is : -4.999828065806665
# local minimum occurs at  -4.999828065806665
# Iteration is  533
#  value is : -4.9998315044905315
# local minimum occurs at  -4.9998315044905315
# Iteration is  534
#  value is : -4.999834874400721
# local minimum occurs at  -4.999834874400721
# Iteration is  535
#  value is : -4.999838176912706
# local minimum occurs at  -4.999838176912706
# Iteration is  536
#  value is : -4.999841413374452
# local minimum occurs at  -4.999841413374452
# Iteration is  537
#  value is : -4.999844585106963
# local minimum occurs at  -4.999844585106963
# Iteration is  538
#  value is : -4.999847693404824
# local minimum occurs at  -4.999847693404824
# Iteration is  539
#  value is : -4.999850739536727
# local minimum occurs at  -4.999850739536727
# Iteration is  540
#  value is : -4.999853724745993
# local minimum occurs at  -4.999853724745993
# Iteration is  541
#  value is : -4.999856650251073
# local minimum occurs at  -4.999856650251073
# Iteration is  542
#  value is : -4.999859517246051
# local minimum occurs at  -4.999859517246051
# Iteration is  543
#  value is : -4.99986232690113
# local minimum occurs at  -4.99986232690113
# Iteration is  544
#  value is : -4.999865080363108
# local minimum occurs at  -4.999865080363108
# Iteration is  545
#  value is : -4.999867778755846
# local minimum occurs at  -4.999867778755846
# Iteration is  546
#  value is : -4.999870423180729
# local minimum occurs at  -4.999870423180729
# Iteration is  547
#  value is : -4.999873014717115
# local minimum occurs at  -4.999873014717115
# Iteration is  548
#  value is : -4.999875554422772
# local minimum occurs at  -4.999875554422772
# Iteration is  549
#  value is : -4.999878043334316
# local minimum occurs at  -4.999878043334316
# Iteration is  550
#  value is : -4.99988048246763
# local minimum occurs at  -4.99988048246763
# Iteration is  551
#  value is : -4.999882872818278
# local minimum occurs at  -4.999882872818278
# Iteration is  552
#  value is : -4.999885215361912
# local minimum occurs at  -4.999885215361912
# Iteration is  553
#  value is : -4.999887511054674
# local minimum occurs at  -4.999887511054674
# Iteration is  554
#  value is : -4.999889760833581
# local minimum occurs at  -4.999889760833581
# Iteration is  555
#  value is : -4.999891965616909
# local minimum occurs at  -4.999891965616909
# Iteration is  556
#  value is : -4.999894126304571
# local minimum occurs at  -4.999894126304571
# Iteration is  557
#  value is : -4.999896243778479
# local minimum occurs at  -4.999896243778479
# Iteration is  558
#  value is : -4.999898318902909
# local minimum occurs at  -4.999898318902909
# Iteration is  559
#  value is : -4.999900352524851
# local minimum occurs at  -4.999900352524851
# Iteration is  560
#  value is : -4.9999023454743545
# local minimum occurs at  -4.9999023454743545
# Iteration is  561
#  value is : -4.999904298564868
# local minimum occurs at  -4.999904298564868
# Iteration is  562
#  value is : -4.9999062125935705
# local minimum occurs at  -4.9999062125935705
# Iteration is  563
#  value is : -4.999908088341699
# local minimum occurs at  -4.999908088341699
# Iteration is  564
#  value is : -4.9999099265748645
# local minimum occurs at  -4.9999099265748645
# Iteration is  565
#  value is : -4.999911728043367
# local minimum occurs at  -4.999911728043367
# Iteration is  566
#  value is : -4.9999134934825
# local minimum occurs at  -4.9999134934825
# Iteration is  567
#  value is : -4.99991522361285
# local minimum occurs at  -4.99991522361285
# Iteration is  568
#  value is : -4.999916919140593
# local minimum occurs at  -4.999916919140593
# Iteration is  569
#  value is : -4.999918580757781
# local minimum occurs at  -4.999918580757781
# Iteration is  570
#  value is : -4.999920209142625
# local minimum occurs at  -4.999920209142625
# Iteration is  571
#  value is : -4.999921804959773
# local minimum occurs at  -4.999921804959773
# Iteration is  572
#  value is : -4.9999233688605775
# local minimum occurs at  -4.9999233688605775
# Iteration is  573
#  value is : -4.999924901483366
# local minimum occurs at  -4.999924901483366
# Iteration is  574
#  value is : -4.999926403453699
# local minimum occurs at  -4.999926403453699
# Iteration is  575
#  value is : -4.999927875384625
# local minimum occurs at  -4.999927875384625
# Iteration is  576
#  value is : -4.999929317876933
# local minimum occurs at  -4.999929317876933
# Iteration is  577
#  value is : -4.999930731519394
# local minimum occurs at  -4.999930731519394
# Iteration is  578
#  value is : -4.999932116889006
# local minimum occurs at  -4.999932116889006
# Iteration is  579
#  value is : -4.999933474551226
# local minimum occurs at  -4.999933474551226
# Iteration is  580
#  value is : -4.999934805060202
# local minimum occurs at  -4.999934805060202
# Iteration is  581
#  value is : -4.999936108958998
# local minimum occurs at  -4.999936108958998
# Iteration is  582
#  value is : -4.999937386779818
# local minimum occurs at  -4.999937386779818
# Iteration is  583
#  value is : -4.999938639044221
# local minimum occurs at  -4.999938639044221
# Iteration is  584
#  value is : -4.999939866263337
# local minimum occurs at  -4.999939866263337
# Iteration is  585
#  value is : -4.99994106893807
# local minimum occurs at  -4.99994106893807
# Iteration is  586
#  value is : -4.999942247559309
# local minimum occurs at  -4.999942247559309
# Iteration is  587
#  value is : -4.999943402608123
# local minimum occurs at  -4.999943402608123
# Iteration is  588
#  value is : -4.9999445345559606
# local minimum occurs at  -4.9999445345559606
# Iteration is  589
#  value is : -4.999945643864842
# local minimum occurs at  -4.999945643864842
# Iteration is  590
#  value is : -4.999946730987545
# local minimum occurs at  -4.999946730987545
# Iteration is  591
#  value is : -4.999947796367794
# local minimum occurs at  -4.999947796367794
# Iteration is  592
#  value is : -4.999948840440438
# local minimum occurs at  -4.999948840440438
# Iteration is  593
#  value is : -4.999949863631629
# local minimum occurs at  -4.999949863631629
# Iteration is  594
#  value is : -4.999950866358997
# local minimum occurs at  -4.999950866358997
# Iteration is  595
#  value is : -4.9999518490318176
# local minimum occurs at  -4.9999518490318176
